# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = np.array([
    [-10,0],
    [-5,0],
    [-7,0],
    [-2,0],
    [0,0],
    [1,1],
    [7,1],
    [6,1],
    [10,1],
    [15,1],
    [9,1]
])

# %%
# Draw dataset
negative_class = dataset[:5]
positive_class = dataset[5:]

# Draw the nevative first and positive
plt.scatter(negative_class[:,0], negative_class[:,1], c = 'y')
plt.scatter(positive_class[:,0], positive_class[:,1], c = 'g')
plt.show()

# %%
def get_prediction(m, b, x):
